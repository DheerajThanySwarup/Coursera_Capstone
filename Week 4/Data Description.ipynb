# %% [markdown]
# # The Battle of Neighbourhood - Week 1

# %% [markdown]
# ### Data Description:

# %% [markdown]
# We will be using a wikipedia page as datasource to get postal code available in Toronto. The geocoder library is used to get geological coordinates latitude and longitude values for all the postal codes.
# Wikipedia Page URL: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# ### Foursquare API:

# %% [markdown]
# We will nee data about venues in different neighbourhoods of that specific borough. In order to gain that information we will use "Forsquare" API service. The API provides detailed information about all the venues near a specified location. The details includes venue names, locations, reviews, photos, etc.
#
# The data retrieved from API contains information of venues within a specified distance from given latitude and longitude of the postal codes. The information obtained per venue as follows:
#
# 1. Neighbourhood
# 2. Neighbourhood Latitude
# 3. Neighbourhood Longitude
# 4. Venue
# 5. Name of the venue
# 6. Venue Latitude
# 7. Venue Longitude
# 8. Venue Category
